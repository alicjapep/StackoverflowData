# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
df.head(7)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[[1,2,3], 'Hobbyist']
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[1:10, 'Hobbyist':'Country']
# Out:
#            Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 1               Yes   NaN         13  Monthly        NaN            NaN
# 2                No   NaN         19      NaN        NaN            NaN
# 3               Yes   NaN         15      NaN        NaN            NaN
# 4               Yes  25.0         18      NaN        NaN            NaN
# 5               Yes  31.0         16      NaN        NaN            NaN
# 6                No   NaN         14      NaN        NaN            NaN
# 7               Yes   NaN         18  Monthly        NaN            NaN
# 8               Yes  36.0         12   Yearly   116000.0       116000.0
# 9                No  30.0         20      NaN        NaN            NaN
# 10              Yes  22.0         14   Yearly    25000.0        32315.0
#
#                        Country
# Respondent
# 1                      Germany
# 2               United Kingdom
# 3           Russian Federation
# ...

# %%
schema_df.loc['Trans', 'QuestionText']
# Out:
# 'Are you transgender?'

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
filt = (df['Trans'] == "Yes") & (df['Age1stCode'] == "20")

# %%
df[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 31                             I am a developer by profession      Yes   NaN
# 2395                           I am a developer by profession      Yes  28.0
# 6550                           I am a developer by profession      Yes  26.0
# 10423       I am not primarily a developer, but I write co...      Yes   NaN
# 14033                          I am a developer by profession      Yes  32.0
# 20122                          I am a developer by profession      Yes   1.0
# 34993                          I am a developer by profession      Yes   NaN
# 42595                          I am a developer by profession       No  60.0
# 49932                          I am a developer by profession       No  28.0
# 50147                          I am a developer by profession       No  28.0
# 53827                          I am a developer by profession      Yes   NaN
# ...

# %%
df.loc[filt,"ConvertedComp"]
# Out:
# Respondent
# 31             NaN
# 2395       72918.0
# 6550       12348.0
# 10423          NaN
# 14033      51704.0
# 20122    1000000.0
# 34993          NaN
# 42595      88900.0
# 49932      52609.0
# 50147     110000.0
# 53827          NaN
# 56080          NaN
# Name: ConvertedComp, dtype: float64

# %%
high_salary = (df["ConvertedComp"] > 70000)

# %%
df.loc[high_salary, ['LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith', 'Country', "Age", "ConvertedComp" ]]
# Out:
#                                            LanguageWorkedWith  \
# Respondent
# 8                                                  Python;SQL
# 16          Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17                      C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18                        Bash/Shell/PowerShell;HTML/CSS;Perl
# 19          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                                                       ...
# 65586                                                     NaN
# 65589                                                     NaN
# 65602                                                     NaN
# 65604                                                     NaN
# 65617                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 8                                                  JavaScript
# 16                                                         Go
# ...

# %%
countries = ['Poland', 'Germany', 'Ukraine']
filterek = df['Country'].isin(countries)

# %%
df.loc[filterek, ['Country', 'ConvertedComp']]
# Out:
#             Country  ConvertedComp
# Respondent
# 1           Germany            NaN
# 6           Germany            NaN
# 23          Germany            NaN
# 24          Germany        91883.0
# 29          Ukraine            NaN
# ...             ...            ...
# 52163       Germany            NaN
# 56163        Poland            NaN
# 56263       Germany            NaN
# 64104        Poland            NaN
# 64925        Poland            NaN
#
# [5707 rows x 2 columns]

# %%
pyton = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[~pyton, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                 C#;HTML/CSS;JavaScript
# 2                       JavaScript;Swift
# 4                                    NaN
# 5                      HTML/CSS;Ruby;SQL
# 6               HTML/CSS;Java;JavaScript
#                       ...
# 64567                                NaN
# 64858                                NaN
# 64898                                NaN
# 64925                           HTML/CSS
# 65112    C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 39174, dtype: object

# %%
# ~ = odwrotne filtrowanie

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace = True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df.sort_values(by=['Country','SalaryUSD'], ascending=[True,False], inplace=True)

# %%
df[['Country','SalaryUSD']].head(60)
# Out:
#                 Country  SalaryUSD
# Respondent
# 62788       Afghanistan  1000000.0
# 65381       Afghanistan  1000000.0
# 65456       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 28374       Afghanistan   130000.0
# 9839        Afghanistan    23328.0
# 63848       Afghanistan    23328.0
# 51862       Afghanistan    20950.0
# 51509       Afghanistan    20220.0
# 44484       Afghanistan    18660.0
# 15422       Afghanistan    18000.0
# 2932        Afghanistan    16335.0
# 26540       Afghanistan    13992.0
# 57269       Afghanistan    10884.0
# 26775       Afghanistan     8016.0
# 30568       Afghanistan     5448.0
# 30522       Afghanistan     4668.0
# 28811       Afghanistan     4509.0
# 34969       Afghanistan     4356.0
# 26857       Afghanistan     2328.0
# 33878       Afghanistan     1860.0
# 35753       Afghanistan      780.0
# 18049       Afghanistan      109.0
# 35295       Afghanistan        0.0
# 898         Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(20)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# 724      2000000.0
# 818      2000000.0
# 986      2000000.0
# 1022     2000000.0
# 1036     2000000.0
# 1117     2000000.0
# 1128     2000000.0
# 1193     2000000.0
# 1296     2000000.0
# 1345     2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5725                           I am a developer by profession    False  26.0
# 54263                          I am a developer by profession     True  29.0
# 43430                          I am a developer by profession     True  33.0
# 59279                          I am a developer by profession     True   NaN
# 46711                          I am a developer by profession     True   NaN
# 123                            I am a developer by profession     True  26.0
# 125         I am not primarily a developer, but I write co...     True  41.0
# 193                            I am a developer by profession     True  29.0
# 665                            I am a developer by profession     True  24.0
# 699         I am not primarily a developer, but I write co...     True  39.0
#
#                       Age1stCode CompFreq     CompTotal  SalaryUSD  \
# Respondent
# ...

# %%
df['SalaryUSD'].median()
# Out:
# 54049.0

# %%
df.describe()
# Out:
#                 Age      CompTotal     SalaryUSD   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['SalaryUSD'].count() #people who answered
# Out:
# 34756

# %%
df['Hobbyist']
# Out:
# Respondent
# 62788     True
# 65381    False
# 65456     True
# 38672    False
# 28374     True
#          ...
# 60055    False
# 61121     True
# 61570    False
# 61918     True
# 62605    False
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# True     50388
# False    14028
# Name: Hobbyist, dtype: int64

# %%
df['OpSys'].value_counts(normalize = True) #normalize = true - wartość procentowa
# Out:
# Windows        0.483211
# Linux-based    0.265562
# MacOS          0.250320
# BSD            0.000907
# Name: OpSys, dtype: float64

# %%
schema_df.loc['OpSys', 'QuestionText']
# Out:
# 'What is the primary operating system in which you work?'

# %%
df['Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# North Korea           1
# Fiji                  1
# Lesotho               1
# Liechtenstein         1
# Gabon                 1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 123                            I am a developer by profession     True  26.0
# 125         I am not primarily a developer, but I write co...     True  41.0
# 193                            I am a developer by profession     True  29.0
# 665                            I am a developer by profession     True  24.0
# 699         I am not primarily a developer, but I write co...     True  39.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN     True  32.0
# 58896                                                     NaN     True  29.0
# 60931                                                     NaN     True   NaN
# 63077                                                     NaN     True   NaN
# 64858                                                     NaN     True   NaN
#
# ...

# %%
filtr = df['Country'] == 'India'
df.loc[filtr, 'OpSys']
# Out:
# Respondent
# 37655          MacOS
# 36976            NaN
# 3332           MacOS
# 8457     Linux-based
# 21351            BSD
#             ...
# 54757    Linux-based
# 55407            NaN
# 62464            NaN
# 62954            NaN
# 64236            NaN
# Name: OpSys, Length: 8403, dtype: object

# %%
country_grp['OpSys'].value_counts().head(50)
# Out:
# Country      OpSys
# Afghanistan  Windows         31
#              Linux-based      8
#              MacOS            5
# Albania      Windows         24
#              MacOS            7
#              Linux-based      6
# Algeria      Windows         44
#              Linux-based     25
#              MacOS            5
#              BSD              1
# Andorra      Linux-based      4
#              Windows          2
#              BSD              1
# Angola       Windows          3
#              Linux-based      1
# Argentina    Windows        142
#              Linux-based    129
#              MacOS           75
# Armenia      Linux-based     21
#              Windows         20
#              MacOS           10
# Australia    Windows        513
#              MacOS          387
#              Linux-based    211
# Austria      Windows        274
#              Linux-based    154
#              MacOS           76
# Azerbaijan   Windows         25
# ...

# %%
country_grp['OpSys'].value_counts().loc['China']
# Out:
# OpSys
# Windows        152
# MacOS           65
# Linux-based     64
# BSD              1
# Name: OpSys, dtype: int64

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean'])
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python.loc['Poland']
# Out:
# 509

# %%
filtr1=df['Country'] == 'India'
df.loc[filtr1]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
country_respondents = df['Country'].value_counts()
country_respondents.loc['Poland']
# Out:
# 1278

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort = False)
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# ...                 ...                 ...
# North Korea           1                   0
# Fiji                  1                   0
# Lesotho               1                   0
# Liechtenstein         1                   0
# Gabon                 1                   1
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                 NumRespondents  NumKnowsPython
# United States            12469            5964
# India                     8403            2670
# United Kingdom            3896            1621
# Germany                   3890            1712
# Canada                    2191            1011
# ...                        ...             ...
# North Korea                  1               0
# Fiji                         1               0
# Lesotho                      1               0
# Liechtenstein                1               0
# Gabon                        1               1
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                 NumRespondents  NumKnowsPython  PctKnowsPython
# United States            12469            5964       47.830620
# India                     8403            2670       31.774366
# United Kingdom            3896            1621       41.606776
# Germany                   3890            1712       44.010283
# Canada                    2191            1011       46.143314
# ...                        ...             ...             ...
# North Korea                  1               0        0.000000
# Fiji                         1               0        0.000000
# Lesotho                      1               0        0.000000
# Liechtenstein                1               0        0.000000
# Gabon                        1               1      100.000000
#
# [183 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    297.000000
# NumKnowsPython    132.000000
# PctKnowsPython     44.444444
# Name: Japan, dtype: float64
